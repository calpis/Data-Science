# %%
import nbimporter
import functions
reload(functions)
import pandas as pd
from sklearn.cluster import KMeans, MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import OrderedDict
import numpy as np
import itertools
#viz
from datetime import date
from random import randint
import math

from bokeh.models import ColumnDataSource
from bokeh.models.widgets import DataTable, DateFormatter, TableColumn
from bokeh.io import output_file, show

from sklearn import ensemble
from sklearn.metrics.pairwise import linear_kernel
from dateutil import parser

from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.stattools import arma_order_select_ic
from matplotlib import pyplot

#from bokeh.io import vform
# Out:
# Importing Jupyter notebook from functions.ipynb
# Importing Jupyter notebook from functions.ipynb
# /Users/momori/anaconda2/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
import splunklib.client as client
import httplib
import urllib
from xml.etree import ElementTree
import ssl

# %%
from splunklib.binding import HTTPError
import splunklib.client as client

# %%
HOST = "oprdebshe300.corp.intuit.net"
PORT = 8089
USERNAME = "ebs_rest"
PASSWORD = "ebs_rest"

# Present credentials to Splunk and retrieve the session key
connection = httplib.HTTPSConnection(HOST, PORT,context=ssl._create_unverified_context())
body = urllib.urlencode({'username': USERNAME, 'password': PASSWORD})
headers = { 
    'Content-Type': "application/x-www-form-urlencoded", 
    'Content-Length': str(len(body)),
    'Host': HOST,
    'User-Agent': "a.py/1.0",
    'Accept': "*/*"
}

print 'connecting'

try:
    connection.request("POST", "/services/auth/login", body, headers)
    print 'here'
    response = connection.getresponse()
finally:
    print 'closing'
    connection.close()
    print 'closed'
if response.status != 200:
    raise Exception, "%d (%s)" % (response.status, response.reason)
print 'reading'
body = response.read()
print 'read'
#sessionKey = ElementTree.XML(body).findtext("./sessionKey")
# Out:
# connecting
# here
# closing
# closed
# reading
# read

# %%
import splunklib.results as results
import splunklib.client as client

service = client.Service(host=HOST, port=PORT, username=USERNAME, password=PASSWORD)
service.login()
# Run a one-shot search and display the results using the results reader

# Set the parameters for the search:
# - Search everything in a 24-hour time range starting June 19, 12:00pm
# - Display the first 10 results
kwargs_oneshot = {"earliest_time": "2017-06-19T12:00:00.000-07:00",
                  "latest_time": "2017-06-19T12:02:00.000-07:00"}
searchquery_oneshot = "search * | head 10"

oneshotsearch_results = service.jobs.oneshot(searchquery_oneshot, **kwargs_oneshot)

# Get the results and display them using the ResultsReader
reader = results.ResultsReader(oneshotsearch_results)
for item in reader:
    print(item)
# Out:
# OrderedDict([('_bkt', 'ininicwsprod_app~4388~879616DC-ACFF-4A52-8210-37E34DA37E7C'), ('_cd', '4388:319821849'), ('_indextime', '1497898921'), ('_raw', '2017-06-19 12:01:59:999 INFO  ConversationQueueSubscriber:173 - Conversation Subscription URL- http://ind1011c2sm01.intu.inin.local:8018/icws/1232321000/messaging/subscriptions/queues/Interaction_CxT_Empirix_Agent_Test2_ACD1 session- ININsession [session=1232321000, token=WAljY3NfYWRtaW5YJElDV1MgSmF2YVNjcmlwdCBEaXJlY3QgVXNhZ2UgRXhhbXBsZVgkZGQ4NjZhMWUtM2NmMy00NzFjLTgwM2UtODJmZmE3YWUwMzQyWA4xMC4xNjQuMjI3LjEyOA==, cookie=icws_1232321000=77f6496e-b6ae-4798-82dc-daef811ea288|languageId=en-us, url=http://ind1011c2sm01.intu.inin.local:8018/icws/, managerId=null]'), ('_serial', '0'), ('_si', ['oprdebsix411.corp.intuit.net', 'ininicwsprod_app']), ('_sourcetype', 'conversation_jobs'), ('_subsecond', '.999'), ('_time', '2017-06-19T12:01:59.999-07:00'), ('host', 'pprdcipor405.corp.intuit.net'), ('index', 'ininicwsprod_app'), ('linecount', '1'), ('source', '/app/icws/AllApplicationLogs/ics_conversations_jobs_1.log'), ('sourcetype', 'conversation_jobs'), ('splunk_server', 'oprdebsix411.corp.intuit.net')])
# OrderedDict([('_bkt', 'caasprod_app~4729~C1122FD7-AE0C-4EB9-A39A-24BFBCB0EAE6'), ('_cd', '4729:735376272'), ('_indextime', '1497898920'), ('_raw', '2017-06-19 12:01:59,999 [org.springframework.jms.listener.DefaultMessageListenerContainer#5-5] INFO  c.i.s.s.impl.AccountServiceProvider -    Updating Account - txnId=295881bf-8c30-44b1-a6fc-dd9ccf76f3ee :  appid=Intuit.cto.iam.ius : txnTimeStamp=06/19/2017 12:01:59.998 PDT : messageReprocess=false : country=US : realmId=193514527837809 : eventType=UPDATEREALMS :  payload=null : can=null    '), ('_serial', '0'), ('_si', ['oprdebsix310.corp.intuit.net', 'caasprod_app']), ('_sourcetype', 'CaaS_Prod'), ('_subsecond', '.999'), ('_time', '2017-06-19T12:01:59.999-07:00'), ('host', 'pprdcoras400.corp.intuit.net'), ('index', 'caasprod_app'), ('linecount', '1'), ('source', '/app/apache-tomcat-8.0.33/logs/crmservices-integration.log'), ('sourcetype', 'CaaS_Prod'), ('splunk_server', 'oprdebsix310.corp.intuit.net')])
# OrderedDict([('_bkt', 'caasprod_app~4729~C1122FD7-AE0C-4EB9-A39A-24BFBCB0EAE6'), ('_cd', '4729:735376255'), ('_indextime', '1497898920'), ('_raw', '2017-06-19 12:01:59,999 [org.springframework.jms.listener.DefaultMessageListenerContainer#5-5] DEBUG c.i.s.h.i.RealmsUpdateEventHandlerImpl -    txnId=295881bf-8c30-44b1-a6fc-dd9ccf76f3ee : RealmId=193514527837809 REALM_UPDATE={"realmId":"193514527837809","displayName":["YL Properties"],"serviceAccount":false,"address":[],"phone":[],"alternateEmail":[],"product":[],"creditCard":[],"bankAccount":[],"taxIdentifier":[],"persona":[],"grant":[],"attribute":[],"clientAccessInfo":[]}    '), ('_serial', '1'), ('_si', ['oprdebsix310.corp.intuit.net', 'caasprod_app']), ('_sourcetype', 'CaaS_Prod'), ('_subsecond', '.999'), ('_time', '2017-06-19T12:01:59.999-07:00'), ('host', 'pprdcoras400.corp.intuit.net'), ('index', 'caasprod_app'), ('linecount', '1'), ('source', '/app/apache-tomcat-8.0.33/logs/crmservices-integration.log'), ('sourcetype', 'CaaS_Prod'), ('splunk_server', 'oprdebsix310.corp.intuit.net')])
# OrderedDict([('_bkt', 'caasprod_app~4729~C1122FD7-AE0C-4EB9-A39A-24BFBCB0EAE6'), ('_cd', '4729:735376234'), ('_indextime', '1497898920'), ('_raw', '2017-06-19 12:01:59,998 [org.springframework.jms.listener.DefaultMessageListenerContainer#5-5] INFO  c.i.s.j.c.OIIEventMessageConsumer -    txnId=295881bf-8c30-44b1-a6fc-dd9ccf76f3ee :  appid=Intuit.cto.iam.ius : txnTimeStamp=06/19/2017 12:01:59.998 PDT : messageReprocess=false : country=US : realmId=null : eventType=UPDATEREALMS :  payload={"realmId":"193514527837809","displayName":["YL Properties"],"serviceAccount":false,"address":[],"phone":[],"alternateEmail":[],"product":[],"creditCard":[],"bankAccount":[],"taxIdentifier":[],"persona":[],"grant":[],"attribute":[],"clientAccessInfo":[]}    '), ('_serial', '2'), ('_si', ['oprdebsix310.corp.intuit.net', 'caasprod_app']), ('_sourcetype', 'CaaS_Prod'), ('_subsecond', '.998'), ('_time', '2017-06-19T12:01:59.998-07:00'), ('host', 'pprdcoras400.corp.intuit.net'), ('index', 'caasprod_app'), ('linecount', '1'), ('source', '/app/apache-tomcat-8.0.33/logs/crmservices-integration.log'), ('sourcetype', 'CaaS_Prod'), ('splunk_server', 'oprdebsix310.corp.intuit.net')])
# OrderedDict([('_bkt', 'qbnsubscriptionws-prd~40~C1122FD7-AE0C-4EB9-A39A-24BFBCB0EAE6'), ('_cd', '40:394812029'), ('_indextime', '1497898921'), ('_raw', '20170619.120159.997 Mo INFO - http-nio-8080-exec-60/scripts/subisapi.dll Service Request details: ,requestName=ISUBSCRIPTION_GETORDERNUMBER, requestResponseTime(milliseconds)=2'), ('_serial', '3'), ('_si', ['oprdebsix310.corp.intuit.net', 'qbnsubscriptionws-prd']), ('_sourcetype', 'tomcat-platform-logs'), ('_subsecond', '.997'), ('_time', '2017-06-19T12:01:59.997-07:00'), ('host', 'pprdswsap301.corp.intuit.net'), ('index', 'qbnsubscriptionws-prd'), ('linecount', '1'), ('source', '/shared/subscriptionws.sitedata/logs/pprdswsap301/platform.log'), ('sourcetype', 'tomcat-platform-logs'), ('splunk_server', 'oprdebsix310.corp.intuit.net')])
# OrderedDict([('_bkt', 'qbnsubscriptionws-prd~40~C1122FD7-AE0C-4EB9-A39A-24BFBCB0EAE6'), ('_cd', '40:394812022'), ('_indextime', '1497898921'), ('_raw', '20170619.120159.997 Mo INFO - http-nio-8080-exec-30/scripts/subisapi.dll Service Request details: ,requestName=ISUBSCRIPTION_VALIDATE, requestResponseTime(milliseconds)=3'), ('_serial', '4'), ('_si', ['oprdebsix310.corp.intuit.net', 'qbnsubscriptionws-prd']), ('_sourcetype', 'tomcat-platform-logs'), ('_subsecond', '.997'), ('_time', '2017-06-19T12:01:59.997-07:00'), ('host', 'pprdswsap301.corp.intuit.net'), ('index', 'qbnsubscriptionws-prd'), ('linecount', '1'), ('source', '/shared/subscriptionws.sitedata/logs/pprdswsap301/platform.log'), ('sourcetype', 'tomcat-platform-logs'), ('splunk_server', 'oprdebsix310.corp.intuit.net')])
# OrderedDict([('_bkt', 'qbnsubscriptionws-prd~40~C1122FD7-AE0C-4EB9-A39A-24BFBCB0EAE6'), ('_cd', '40:394809831'), ('_indextime', '1497898921'), ('_raw', '20170619.120159.997 Mo I perf http-nio-8080-exec-60/scripts/subisapi.dll perf SubscriptionServlet 3 1 16813992 132644864 getSubscriptionOrderNumber:2 doPost:null=:3 handleServletRequest:null::1'), ('_serial', '5'), ('_si', ['oprdebsix310.corp.intuit.net', 'qbnsubscriptionws-prd']), ('_sourcetype', 'tomcat-perf-logs'), ('_subsecond', '.997'), ('_time', '2017-06-19T12:01:59.997-07:00'), ('host', 'pprdswsap301.corp.intuit.net'), ('index', 'qbnsubscriptionws-prd'), ('linecount', '1'), ('source', '/shared/subscriptionws.sitedata/logs/pprdswsap301/perf.log'), ('sourcetype', 'tomcat-perf-logs'), ('splunk_server', 'oprdebsix310.corp.intuit.net')])
# OrderedDict([('_bkt', 'qbnsubscriptionws-prd~40~C1122FD7-AE0C-4EB9-A39A-24BFBCB0EAE6'), ('_cd', '40:394809823'), ('_indextime', '1497898921'), ('_raw', '20170619.120159.997 Mo I perf http-nio-8080-exec-30/scripts/subisapi.dll perf SubscriptionServlet 4 2 16859288 132644864 doPost:null=:4 handleServletRequest:null::1 validateSubscription:3'), ('_serial', '6'), ('_si', ['oprdebsix310.corp.intuit.net', 'qbnsubscriptionws-prd']), ('_sourcetype', 'tomcat-perf-logs'), ('_subsecond', '.997'), ('_time', '2017-06-19T12:01:59.997-07:00'), ('host', 'pprdswsap301.corp.intuit.net'), ('index', 'qbnsubscriptionws-prd'), ('linecount', '1'), ('source', '/shared/subscriptionws.sitedata/logs/pprdswsap301/perf.log'), ('sourcetype', 'tomcat-perf-logs'), ('splunk_server', 'oprdebsix310.corp.intuit.net')])
# OrderedDict([('_bkt', 'qbnsubscriptionws-prd~42~9906B8CC-990D-4B7A-9A63-860676ABC497'), ('_cd', '42:201676438'), ('_indextime', '1497898922'), ('_raw', '20170619.120159.996 Mo INFO - http-nio-8080-exec-8/scripts/subisapi.dll Service Request details: ,requestName=ISUBSCRIPTION_GETBYSUBSCRIPTIONNUMBER, requestResponseTime(milliseconds)=12'), ('_serial', '0'), ('_si', ['oprdebsix311.corp.intuit.net', 'qbnsubscriptionws-prd']), ('_sourcetype', 'tomcat-platform-logs'), ('_subsecond', '.996'), ('_time', '2017-06-19T12:01:59.996-07:00'), ('host', 'pprdswsap302.corp.intuit.net'), ('index', 'qbnsubscriptionws-prd'), ('linecount', '1'), ('source', '/shared/subscriptionws.sitedata/logs/pprdswsap302/platform.log'), ('sourcetype', 'tomcat-platform-logs'), ('splunk_server', 'oprdebsix311.corp.intuit.net')])
# OrderedDict([('_bkt', 'qbnsubscriptionws-prd~42~9906B8CC-990D-4B7A-9A63-860676ABC497'), ('_cd', '42:201674028'), ('_indextime', '1497898922'), ('_raw', '20170619.120159.996 Mo I perf http-nio-8080-exec-8/scripts/subisapi.dll perf SubscriptionServlet 12 1 936168968 1527250944 getSubscriptionBySubscriptionNumber:3 doPost:null=:12 getSubscrServiceBySubscriptionNumber:3 handleServletRequest:null::0 getSubscriberBySubscriptionNumber:3 getPlan:3'), ('_serial', '1'), ('_si', ['oprdebsix311.corp.intuit.net', 'qbnsubscriptionws-prd']), ('_sourcetype', 'tomcat-perf-logs'), ('_subsecond', '.996'), ('_time', '2017-06-19T12:01:59.996-07:00'), ('host', 'pprdswsap302.corp.intuit.net'), ('index', 'qbnsubscriptionws-prd'), ('linecount', '1'), ('source', '/shared/subscriptionws.sitedata/logs/pprdswsap302/perf.log'), ('sourcetype', 'tomcat-perf-logs'), ('splunk_server', 'oprdebsix311.corp.intuit.net')])

# %%
##variables
look_back = 2

# %%
functions.test()
# Out:
# 'test1'

# %%
new_file = 'new_logs'

df_new = pd.read_csv(new_file)
df_new.head()
# Out:
#    Unnamed: 0                        _time  \
# 0           0  2017-08-14 02:59:24.194 PDT
# 1           1  2017-08-14 02:53:20.465 PDT
# 2           2  2017-08-14 02:52:40.441 PDT
# 3           3  2017-08-14 02:52:06.904 PDT
# 4           4  2017-08-14 02:46:45.124 PDT
#
#                                                 _raw
# 0  ERROR 2017-08-14 02:59:24,194 [[commerce-order...
# 1  ERROR 2017-08-14 02:53:20,465 [[commerce-order...
# 2  ERROR 2017-08-14 02:52:40,441 [[commerce-order...
# 3  ERROR 2017-08-14 02:52:06,904 [[commerce-order...
# 4  ERROR 2017-08-14 02:46:45,124 [[commerce-entit...

# %%
log_file = '/Users/momori/Documents/projects/log_monitoring/muleprep_app_ERROR.csv'
log_file1 = '/Users/momori/Documents/projects/log_monitoring/muleprod_app_aug_7.csv'
log_file2 = '/Users/momori/Documents/projects/log_monitoring/muleprod_app_aug_1.csv'
log_file3 = '/Users/momori/Documents/projects/log_monitoring/muleprep_app_ERROR.csv'
log_file4 = '/Users/momori/Documents/projects/log_monitoring/muleprep_app_ERROR.csv'



df_test = pd.read_csv(log_file)
df_train1 = pd.read_csv(log_file)#1)
df_train2 = pd.read_csv(log_file)#2)
# Out:
# /Users/momori/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (0,1,2,4,5,6,7,8,10,11,12,13,14,15,18,19,20,21,22,23,25,26,28,29,30,31,33,34,36,38,40,41,42,45,46,48,49,50,52,53,54,55,56,57,59,60,63,64,65,68,69,70,72,73,74,75,76,77,79,80,81,82,83,87,89,90,91,100,101,102,105,107,108,109,110,111,112,114,115,116,117,119,122,123,124,126,127,128,129,130,131,133,135,136,137,139,142,143,144,145,146,148,149,150,154,155,156,158,159,160,161,169,171,172,173,174,175,176,177,178,179,181,183,184,185,186,194,196,198,200,201,202,204,209,214,217,218,219,220,224,225,227,229,230,231,232,233,234,235,238,242,243) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
train_df = [df_train1, df_train2]
train_df = [df_new]

# %% [markdown]
# ## Functions

# %%
##km: clustering model
##vecetorizer: document vectorizer
##document: document to cluster
def predict_document_cluster(km, vectorizer, document):
    doc = vectorizer.transform([document])
    return km.predict(doc)

def format_df(df):
    r_df = df.dropna(axis=1)
    r_df.loc[:,'_time'] = r_df['_time'].apply(lambda x: format_time(x))
    return r_df

def format_time(string):
    ##may need smarter logic. seems slow
    return parser.parse(string)

##step_time in minutes
##
## returns: dict. key is timestamp, value is dataframe
def split_by_time(df, step_time=30):
    r_dict = {}
    t=str(step_time)+'Min'
    
    #set _time to index
    tmp = df.set_index(1)
    tmp = tmp.groupby(pd.TimeGrouper(freq=t))
    for key, item in tmp:
        try:
            r_dict[str(key)] = tmp.get_group(key)
        except:
            r_dict[str(key)] = None
    return r_dict
        
def show_top_words(km, vect, show=False, save=True, out_filename='output'):
    dcluster_words = {}
    if show:
        print("Top terms per cluster:")

    order_centroids = km.cluster_centers_.argsort()[:, ::-1]

    terms = vect.get_feature_names()
    for i in range(k):
        if show:
            print("Cluster %d:" % i)
            for ind in order_centroids[i, :10]:
                print(' %s' % terms[ind])
        if save:
            words = []
            for ind in order_centroids[i, :10]:
                words.append(terms[ind])
            dcluster_words[i] = words
    if save:
        np.save(out_filename, dcluster_words)

# %%
# d = np.load('output.npy').item()
# for k,v1 in d.iteritems():
#     print k,v1

# %%
llogs_train = []
llogs_train.append(df_new['_raw'].tolist())

# %%
llogs_train = []
for i in range(look_back):
    llogs_train.append(train_df[i]['_raw'].tolist())
logs_test = df_test['_raw'].tolist()


#logs_train1 = df_train1['_raw'].tolist()
#logs_train2 = df_train2['_raw'].tolist()
#logs_test = df_test['_raw'].tolist()

# %%
m = [[1,2],[3,4]]
list(itertools.chain(*m))
# Out:
# [1, 2, 3, 4]

# %%
##Fit a vectorizer
vect = TfidfVectorizer(max_df = 0.5, min_df = 2, stop_words='english')

#v is base vectorizer, can be used to transform other logs.
ve = vect.fit(list(itertools.chain(*llogs_train)))

#x is the tfidf sparse matrix created for this set of logs
l_vectors = []
for i in range(min(look_back, len(llogs_train))):
    l_vectors.append(ve.transform(llogs_train[i]))
#x1 = v.transform(logs_train1)
#x2 = v.transform(logs_train2)

#make a matrix using all data
input_matrix = ve.transform(list(itertools.chain(*llogs_train)))

# %%
##create kmeans model and fit
k=20
km = MiniBatchKMeans(n_clusters=k, init='k-means++', n_init=1,
                         init_size=1000, batch_size=1000)
km.fit(input_matrix)
# Out:
# MiniBatchKMeans(batch_size=1000, compute_labels=True, init='k-means++',
#         init_size=1000, max_iter=100, max_no_improvement=10, n_clusters=20,
#         n_init=1, random_state=None, reassignment_ratio=0.01, tol=0.0,
#         verbose=0)

# %%
##Let's use cluster 6 as it shows '500' as one of the top words
show_top_words(km, vect, show=True, save=True)
# Out:
# Top terms per cluster:
# Cluster 0:
#  payment
#  information
#  auth
#  service
#  order
#  invalid
#  failed
#  errors
#  code
#  type
# Cluster 1:
#  java
#  org
#  mule
#  extendedschemavalidationfilter
#  runtimeexception
#  wrapper
#  lang
#  222
#  exceptions
#  schemavalidation
# Cluster 2:
#  entitlement
#  06
#  17
#  entitledoffering
#  entitlementofferingrestransformer
#  transformer
#  received
#  connectorwithoutmulesession
#  02
#  cas
# Cluster 3:
#  00
#  currency
#  usd
#  ns1
#  globalsalestax
#  productclass
#  totalcredit
#  salestaxheader
#  documentid
#  taxtype
# Cluster 4:
#  6323
#  304
#  31
#  billingprofiles
#  10
#  jettyconnector
#  util
#  02
#  transformer
#  service
# Cluster 5:
#  schemavalidationfilter
#  validate
#  multiple
#  apparently
#  rejected
#  globalsalestax
#  extendedschemavalidationfilter
#  schemavalidation
#  failed
#  default
# Cluster 6:
#  licensenumber
#  missing
#  parameter
#  required
#  errors
#  202103
#  code
#  type
#  ent
#  entitledofferings
# Cluster 7:
#  f8f30e8ad4bd
#  b8f0da82
#  371b
#  6568
#  695c
#  9bd2
#  29
#  account
#  27
#  enterpriseaccount
# Cluster 8:
#  avs
#  payment
#  auth
#  order
#  service
#  invalid
#  failed
#  201550
#  errors
#  code
# Cluster 9:
#  restrictions
#  rps
#  ebcs
#  httpnosessionconnector
#  4628
#  09
#  25
#  031
#  00
#  rejected
# Cluster 10:
#  customeraccountnumber
#  provided
#  invalid
#  moreinfo
#  errors
#  code
#  type
#  202106
#  ent
#  entitledofferings
# Cluster 11:
#  net
#  java
#  org
#  true
#  80
#  factory
#  endpoint
#  session
#  transport
#  false
# Cluster 12:
#  6335
#  mule
#  enterpriseaccount
#  6dc10132
#  50ad
#  350253329de3
#  78dc
#  37
#  4448
#  main
# Cluster 13:
#  entitlement
#  entitlementofferingrestransformer
#  entitledoffering
#  transformer
#  received
#  connectorwithoutmulesession
#  45
#  cas
#  5309
#  02
# Cluster 14:
#  processor
#  loggermessageprocessor
#  mule
#  failure
#  mdm
#  api
#  org
#  enterpriseaccount
#  received
#  53
# Cluster 15:
#  account
#  enterpriseaccount
#  fdc2
#  3b01a6a7
#  51
#  a5f1
#  6355
#  1b6f2c45d63d
#  870a
#  34
# Cluster 16:
#  order
#  server
#  errors
#  code
#  type
#  201520
#  ordr
#  jettyconnector
#  failed
#  calling
# Cluster 17:
#  code
#  invalid
#  06
#  43
#  account
#  errors
#  type
#  36
#  order
#  jettyconnector
# Cluster 18:
#  customerid
#  customer
#  country
#  postalcode
#  rps
#  ebcs
#  restrictions
#  xmlns
#  city
#  031
# Cluster 19:
#  entitlement
#  entitlementofferingrestransformer
#  entitledoffering
#  transformer
#  5266
#  received
#  46
#  connectorwithoutmulesession
#  45
#  02

# %%
#for i in range(20):
#    print i, len(df_predict1[df_predict1[2]==i]), len(df_predict2[df_predict2[2]==i])

# %%
#goal: create df with columns [logs, times, labels] for each 
l_formatted_df = []
for i in range(min(look_back, len(llogs_train))):
    formatted_df = format_df(train_df[i])
    times = formatted_df['_time'].tolist()
    mat = ve.transform(llogs_train[i])
    labels = km.predict(mat)
    lst = zip(llogs_train[i], times, labels.tolist())
    tmp_df = pd.DataFrame(lst)
    l_formatted_df.append(tmp_df)

# %%
l_formatted_df[0].to_csv('new_df_formatted')

# %% [markdown]
# # Need to add some logic so if no results in a given 30 minute interval, will put a 0 count
#
# maybe done with the try/except clause change

# %%
#split by cluster number
d_cluster_to_od = {}
for cluster_num in range(k):
    l_df = []
    for i in range(look_back):
        filtered_df = l_formatted_df[i][l_formatted_df[i][2]==cluster_num]
        l_df.append(OrderedDict(sorted(split_by_time(filtered_df).items())))
    d_cluster_to_od[cluster_num] = l_df

# %%
##from the ordered dict, get the counts
##d_counts is a dictionary of dictionary. {cluster_num: {timestamp: [count]}}
d_counts = {}
for cluster_num in range(k):
    for odict in d_cluster_to_od[cluster_num]:
        for timestamp, df in odict.iteritems():
            inner_dict = OrderedDict()
            try: 
                count = df.shape[0]
            except:
                count = 0
            if cluster_num not in d_counts.keys():
                #new entry in d_counts. Create inner dict
                inner_dict[timestamp] = [count]
                d_counts[cluster_num] = inner_dict
            elif timestamp not in d_counts[cluster_num].keys():
                #inner dict is there. add new key/value pair
                d_counts[cluster_num][timestamp] = [count]
            else:
                #cluster num is there and timestamp is there. then we append
                d_counts[cluster_num][timestamp].append(count)

# %%
##now for each cluster_num, can use ARIMA model to predict.
for cluster_num in range(k):
    d_timestamp_counts = d_counts[cluster_num]
    for time, counts in d_timestamp_counts.iteritems():
        print time, counts
# Out:
# 2017-08-18 15:00:00-07:00 [38, 38]
# 2017-08-18 15:30:00-07:00 [299, 299]
# 2017-08-18 16:00:00-07:00 [311, 311]
# 2017-08-18 16:30:00-07:00 [2, 2]
# 2017-08-18 17:00:00-07:00 [4, 4]
# 2017-08-18 17:30:00-07:00 [12, 12]
# 2017-08-18 18:00:00-07:00 [300, 300]
# 2017-08-18 18:30:00-07:00 [0, 0]
# 2017-08-18 19:00:00-07:00 [0, 0]
# 2017-08-18 19:30:00-07:00 [1, 1]
# 2017-08-18 20:00:00-07:00 [296, 296]
# 2017-08-18 20:30:00-07:00 [0, 0]
# 2017-08-18 21:00:00-07:00 [0, 0]
# 2017-08-18 21:30:00-07:00 [0, 0]
# 2017-08-18 22:00:00-07:00 [300, 300]
# 2017-08-18 22:30:00-07:00 [4, 4]
# 2017-08-18 23:00:00-07:00 [4, 4]
# 2017-08-18 23:30:00-07:00 [0, 0]
# 2017-08-19 00:00:00-07:00 [20, 20]
# 2017-08-19 00:30:00-07:00 [0, 0]
# 2017-08-19 01:00:00-07:00 [0, 0]
# 2017-08-19 01:30:00-07:00 [0, 0]
# 2017-08-19 02:00:00-07:00 [0, 0]
# 2017-08-19 02:30:00-07:00 [0, 0]
# 2017-08-19 03:00:00-07:00 [0, 0]
# 2017-08-19 03:30:00-07:00 [0, 0]
# 2017-08-19 04:00:00-07:00 [0, 0]
# 2017-08-19 04:30:00-07:00 [0, 0]
# 2017-08-19 05:00:00-07:00 [0, 0]
# 2017-08-19 05:30:00-07:00 [0, 0]
# 2017-08-19 06:00:00-07:00 [0, 0]
# 2017-08-19 06:30:00-07:00 [0, 0]
# 2017-08-19 07:00:00-07:00 [0, 0]
# 2017-08-19 07:30:00-07:00 [20, 20]
# 2017-08-19 08:00:00-07:00 [8, 8]
# 2017-08-19 08:30:00-07:00 [0, 0]
# 2017-08-19 09:00:00-07:00 [0, 0]
# 2017-08-19 09:30:00-07:00 [0, 0]
# 2017-08-19 10:00:00-07:00 [8, 8]
# 2017-08-19 10:30:00-07:00 [0, 0]
# 2017-08-19 11:00:00-07:00 [0, 0]
# 2017-08-19 11:30:00-07:00 [0, 0]
# 2017-08-19 12:00:00-07:00 [12, 12]
# 2017-08-19 12:30:00-07:00 [0, 0]
# 2017-08-19 13:00:00-07:00 [0, 0]
# 2017-08-19 13:30:00-07:00 [15, 15]
# 2017-08-19 14:00:00-07:00 [8, 8]
# 2017-08-19 01:00:00-07:00 [13259, 13259]
# 2017-08-19 01:30:00-07:00 [0, 0]
# 2017-08-19 02:00:00-07:00 [0, 0]
# 2017-08-18 18:00:00-07:00 [300, 300]
# 2017-08-18 18:30:00-07:00 [0, 0]
# 2017-08-18 19:00:00-07:00 [0, 0]
# 2017-08-18 19:30:00-07:00 [0, 0]
# 2017-08-18 20:00:00-07:00 [296, 296]
# 2017-08-18 20:30:00-07:00 [0, 0]
# 2017-08-18 21:00:00-07:00 [0, 0]
# 2017-08-18 21:30:00-07:00 [0, 0]
# 2017-08-18 22:00:00-07:00 [300, 300]
# 2017-08-18 22:30:00-07:00 [0, 0]
# 2017-08-18 23:00:00-07:00 [0, 0]
# 2017-08-18 23:30:00-07:00 [0, 0]
# 2017-08-19 00:00:00-07:00 [20, 20]
# 2017-08-19 00:30:00-07:00 [0, 0]
# 2017-08-19 01:00:00-07:00 [0, 0]
# 2017-08-19 01:30:00-07:00 [0, 0]
# 2017-08-19 02:00:00-07:00 [0, 0]
# 2017-08-19 02:30:00-07:00 [0, 0]
# 2017-08-19 03:00:00-07:00 [0, 0]
# 2017-08-19 03:30:00-07:00 [0, 0]
# 2017-08-19 04:00:00-07:00 [0, 0]
# 2017-08-19 04:30:00-07:00 [0, 0]
# 2017-08-19 05:00:00-07:00 [0, 0]
# 2017-08-19 05:30:00-07:00 [0, 0]
# 2017-08-19 06:00:00-07:00 [0, 0]
# 2017-08-19 06:30:00-07:00 [0, 0]
# 2017-08-19 07:00:00-07:00 [0, 0]
# 2017-08-19 07:30:00-07:00 [8, 8]
# 2017-08-19 08:00:00-07:00 [8, 8]
# 2017-08-19 08:30:00-07:00 [0, 0]
# 2017-08-19 09:00:00-07:00 [0, 0]
# 2017-08-19 09:30:00-07:00 [0, 0]
# 2017-08-19 10:00:00-07:00 [8, 8]
# 2017-08-19 10:30:00-07:00 [0, 0]
# 2017-08-19 11:00:00-07:00 [0, 0]
# 2017-08-19 11:30:00-07:00 [0, 0]
# 2017-08-19 12:00:00-07:00 [8, 8]
# 2017-08-19 12:30:00-07:00 [0, 0]
# 2017-08-19 13:00:00-07:00 [0, 0]
# 2017-08-19 13:30:00-07:00 [0, 0]
# 2017-08-19 14:00:00-07:00 [8, 8]

# %%
# #for each cluster, make a dictionary of counts. eg {0:[100,150,125]}
# d_counts = {}
# for cluster_num in range(k):
#     l_cluster_df = d_cluster_to_df[cluster_num]
#     lst = []
#     for df in l_cluster_df:
#         print df.shape[0]

# %%
print k
# Out:
# 0

# %%
# ##get predictions for a subset of the logs and create df with _raw, _time, and label
# formatted_df = format_df(df_train1)

# logs = formatted_df['_raw'].tolist()
# times = formatted_df['_time'].tolist()
# test_x1 = v.transform(logs)

# labels = km.predict(test_x1)
# lst = zip(logs, times, labels.tolist())
# df_predict1 = pd.DataFrame(lst)
# df_predict1.head()

# ##do same for second train set
# formatted_df = format_df(df_train2)

# logs = formatted_df['_raw'].tolist()
# times = formatted_df['_time'].tolist()
# test_x2 = v.transform(logs)

# labels = km.predict(test_x2)
# lst = zip(logs, times, labels.tolist())
# df_predict2 = pd.DataFrame(lst)
# df_predict2.head()

# %%
df_predict1.shape

# %%
##for each cluster number, create a dt
df_clusters1, df_clusters2 = None

# %%
cluster_num = 8
f_df1 = df_predict1[df_predict1[2]==cluster_num]
f_df2 = df_predict2[df_predict2[2]==cluster_num]
#f_df1 = df_predict1
#f_df2 = df_predict2
f_df1.head()

# %%
check_logs = f_df1[0].tolist()

# %%
check_logs

# %%
##Create dictionary of dataframes, split by time
d1 = OrderedDict(sorted(split_by_time(f_df1).items()))
d2 = OrderedDict(sorted(split_by_time(f_df2).items()))
#d1 = OrderedDict(sorted(split_by_time(df_predict1).items()))
#d2 = OrderedDict(sorted(split_by_time(df_predict2).items()))

# %%
#create counts for training
counts1 = []
counts2 = []
for k, val in d1.iteritems():
    counts1.append(val.shape[0])
for k, val in d2.iteritems():
    counts2.append(val.shape[0])

# %%
len(counts1), len(counts2)

# %%
counts1[:10], counts2[:10]

# %%
v = vect.fit(logs_train1)
v.transform(logs_test)

# %%
##Let's fit the 'future' data and pull out cluster_num
formatted_df = format_df(df_test)
logs_test = formatted_df['_raw'].tolist()
times = formatted_df['_time'].tolist()
test_x1 = v.transform(logs_test)

labels = km.predict(test_x1)
lst = zip(logs, times, labels.tolist())
test_data = pd.DataFrame(lst)
test_data.head()

# %%
test_data = test_data[test_data[2]==cluster_num]

#test_data = test_data
test_d = OrderedDict(sorted(split_by_time(test_data).items()))
test_counts = []
for k, val in test_d.iteritems():
    test_counts.append(val.shape[0])

# %%
test_data.head()

# %%
len(test_counts)

# %%
test_counts[:10]

# %%
#zip the data
counts1 = [float(i) for i in counts1]
counts2 = [float(i) for i in counts2]

train = zip(counts1, counts2)
train = [i for i in train if math.fabs(i[1]-i[0] < 100)]
print len(train)

# %% [markdown]
# ## ARIMA prediction

# %%
##make predictions by fitting ARIMA model into the lists
prediction_upperbound = []
prediction_lowerbound = []
prediction_value = []

for t in train:
    rgr = ARIMA(t, order=(0,0,0))
    fit = rgr.fit(disp=0)
    forecast =  fit.forecast()
    prediction_upperbound.append(forecast[2][0][1])
    prediction_lowerbound.append(forecast[2][0][0])
    prediction_value.append(forecast[0])

#Turn into numpy array for computation
prediction_upperbound = np.asarray(prediction_upperbound)
prediction_lowerbound = np.asarray(prediction_lowerbound)
prediction_value = np.asarray(prediction_value)

# %% [markdown]
# ## Vis

# %%
import numpy as np

from bokeh.plotting import figure, show, output_file

# Define Bollinger Bands.
upperband = prediction_upperbound
lowerband = prediction_lowerbound
x_data = np.arange(1, 101)

length = min(len(prediction_upperbound), len(prediction_lowerbound))
x_data = np.arange(1, length)
# Bollinger shading glyph:
band_x = np.append(x_data, x_data[::-1])
band_y = np.append(lowerband, upperband[::-1])

output_file('bollinger.html', title='Bollinger bands (file)')


p = figure(x_axis_type='datetime', title="")

# add a line renderer
p.line([i for i in range(1,length)], counts2, line_width=2)
p.grid.grid_line_alpha = 0.4
p.x_range.range_padding = 0
p.plot_height = 600
p.plot_width = 800

p.patch(band_x, band_y, color='#7570B3', fill_alpha=0.2)

show(p)

# %%
f = '/Users/momori/PycharmProjects/AIMonitoring/data/qq.csv'
dd = pd.read_csv(f)

# %%
dd
# Out:
#     _serial                        _time  \
mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 3   /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 4   /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 5   /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 6   /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 7   /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 8   /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 9   /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 10  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 11  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 12  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 13  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 14  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 15  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 16   /mule_logs/mule/mule-app-commerce-order-v1.0.log  log4j_mule
# 17  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 18   /mule_logs/mule/mule-app-commerce-order-v1.0.log  log4j_mule
# 19   /mule_logs/mule/mule-app-commerce-order-v1.0.log  log4j_mule
# 20  /mule_logs/mule/mule-app-commerce-account-v2.0...  log4j_mule
# 21  /mule_logs/mule/mule-app-commerce-entitlement-...  log4j_mule
# 22  /mule_logs/mule/mule-app-commerce-account-v2.0...  log4j_mule
# 23  /mule_logs/mule/mule-app-commerce-account-v2.0...  log4j_mule
# 24  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 25   /mule_logs/mule/mule-app-commerce-order-v1.0.log  log4j_mule
# 26   /mule_logs/mule/mule-app-commerce-order-v1.0.log  log4j_mule
# 27  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 28  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 29  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# ..                                                ...         ...
# 55  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 56  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 57  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 58  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 59  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 60  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 61  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 62  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 63  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 64  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 65  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 66  /mule_logs/mule/mule-app-commerce-account-v2.0...  log4j_mule
# 67  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 68  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 69  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 70  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 71  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 72  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 73  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 74  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 75  /mule_logs/mule/mule-app-commerce-entitlement-...  log4j_mule
# 76  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 77  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 78  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 79  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 80  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 81  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
# 82  /mule_logs/mule/mule-app-commerce-entitlement-...  log4j_mule
# 83  /mule_logs/mule/mule-app-commerce-entitlement-...  log4j_mule
# 84  /mule_logs/mule/mule-app-ebcs-restrictions-rps...  log4j_mule
#
#                             host         index                 splunk_server  \
# 0   pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 1   pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 2   pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 3   pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 4   pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 5   pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 6   pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 7   pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 8   pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 9   pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 10  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 11  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 12  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 13  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 14  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 15  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 16  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 17  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 18  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 19  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 20  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 21  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 22  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 23  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 24  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 25  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 26  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 27  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 28  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 29  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# ..                           ...           ...                           ...
# 55  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 56  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 57  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 58  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 59  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 60  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 61  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 62  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 63  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 64  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 65  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 66  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 67  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 68  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 69  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 70  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 71  pprdempa1304.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 72  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 73  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 74  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 75  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 76  pprdempa1303.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 77  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 78  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 79  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix311.corp.intuit.net
# 80  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 81  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 82  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 83  pprdempa1306.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
# 84  pprdempa1305.corp.intuit.net  muleprod_app  oprdebsix310.corp.intuit.net
#
#                                                  _raw
# 0   INFO  2017-08-27 14:35:43,868 [[ebcs-restricti...
# 1   ERROR 2017-08-27 14:35:43,226 [[commerce-entit...
# 2   INFO  2017-08-27 14:35:37,701 [[ebcs-restricti...
# 3   INFO  2017-08-27 14:35:13,728 [[ebcs-restricti...
# 4   INFO  2017-08-27 14:35:13,428 [[ebcs-restricti...
# 5   INFO  2017-08-27 14:35:09,043 [[ebcs-restricti...
# 6   INFO  2017-08-27 14:34:58,891 [[ebcs-restricti...
# 7   INFO  2017-08-27 14:34:49,749 [[ebcs-restricti...
# 8   INFO  2017-08-27 14:34:49,216 [[ebcs-restricti...
# 9   INFO  2017-08-27 14:34:49,174 [[ebcs-restricti...
# 79  INFO  2017-08-27 14:28:17,101 [[ebcs-restricti...
# 80  INFO  2017-08-27 14:27:45,527 [[ebcs-restricti...
# 81      contactInformation=sarah@fetchhotdogco.com...
# 82  ERROR 2017-08-27 14:27:43,632 [[commerce-entit...
# 83  INFO  2017-08-27 14:27:43,631 [[commerce-entit...
# 84  INFO  2017-08-27 14:27:34,079 [[ebcs-restricti...
#
# [85 rows x 8 columns]

# %% [markdown]
# # Test

# %%
##get predictions for a subset of the logs and create df with _raw, _time, and label
test_df = format_df(df[0:10000])

logs = test_df['_raw'].tolist()
times = test_df['_time'].tolist()
test_x = vect.transform(logs)

labels = km.predict(test_x)
lst = zip(logs,times,labels.tolist())
df_predict = pd.DataFrame(lst)
df_predict

# %%
##Create dictionary of dataframes, split by time
d = split_by_time(df_predict)
for k,v in d.iteritems():
    print k, ':::', type(v)

# %%
d['2017-08-19 13:00:00-07:00']

# %%
##Cluster the interval logs by using km.  
#Then get the count for predicting outcomes.

#test out on d
counts = []
for k, v in d.iteritems():
    print k
    counts.append(v.shape[0])

# %%
counts

# %%
##train gradient boosted trees for regression
params = {'n_estimators': 10, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)
clf

# %% [markdown]
# ## Use an ARIMA Model to predict

# %%
floats = [float(i) for i in counts]
floats

# %%
rgr = ARIMA(floats[:len(floats)-1], order=(0,0,0))

# %%
fit = rgr.fit(disp=0)

# %%
fit.forecast()

# %% [markdown]
# ## test area

# %%
import numpy as np

from bokeh.plotting import figure, show, output_file

# Define Bollinger Bands.
upperband = np.random.random_integers(100, 150, size=100)
lowerband = upperband - 100
x_data = np.arange(1, 101)

# Bollinger shading glyph:
band_x = np.append(x_data, x_data[::-1])
band_y = np.append(lowerband, upperband[::-1])

output_file('bollinger.html', title='Bollinger bands (file)')


p = figure(x_axis_type='datetime', title="Bollinger Bands")

# add a line renderer
p.line([0, 20, 30, 40, 50], [80, 130, 135, 90, 90], line_width=4)
p.grid.grid_line_alpha = 0.4
p.x_range.range_padding = 0
p.plot_height = 600
p.plot_width = 800

p.patch(band_x, band_y, color='#7570B3', fill_alpha=0.2)

show(p)

# %%
# from bokeh.plotting import figure, output_file, show
# from bokeh.models.ranges import Range1d
# import numpy


# output_file("line_bar.html")

# p = figure(plot_width=400, plot_height=400)

# # add a line renderer
# p.line([1, 2, 3, 4, 5], [6, 7, 6, 4, 5], line_width=2)

# # setting bar values
# h = numpy.array([2, 8, 5, 10, 7])

# # Correcting the bottom position of the bars to be on the 0 line.
# adj_h = h/2

# # add bar renderer
# p.rect(x=[1, 2, 3, 4, 5], y=adj_h, width=0.4, height=h, color="#CAB2D6")

# # Setting the y  axis range   
# p.y_range = Range1d(0, 12)

# #p.title = "Line and Bar"

# show(p)

# %%
# from bokeh.plotting import figure, output_file, show
# from bokeh.models.ranges import Range1d
# import numpy


# output_file("line_bar.html")
# p = figure(plot_width=400, plot_height=400)

# p.line([1, 2, 3, 4, 5], [6, 7, 6, 4, 5], line_width=2)


# show(p)
