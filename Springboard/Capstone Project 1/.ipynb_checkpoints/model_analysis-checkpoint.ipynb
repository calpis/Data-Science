# %% [markdown]
# ## notes
# maybe not needed. currently model analysis done in the neuralnets notebook

# %% [markdown]
# ## Model analysis
#
# This notebook will focus on analyzing the different models which was created from the models.ipynb notebook, and visualize the accuracies using a heatmap

# %%
#data importing/wrangling
import pandas as pd

#text processing 
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

#CNN modeling
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.embeddings import Embedding
from keras.models import load_model
import os.path



#data split
from sklearn.model_selection import train_test_split

#vizualization
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
plt.style.use('ggplot')

from collections import defaultdict
import pickle

hyper_param_tuning_input = 'hyper_parameter_tuning.pickle'

# %%
post_name=9
file_path = 'keras_model_'+str(post_name)
os.path.exists(file_path)
# Out:
# False

# %% [markdown]
# ## Functions

# %%
def load_keras_models():
    model_list = []
    post_name = 1
    file_path = 'keras_model_'+str(post_name)
    while(os.path.exists(file_path)):
        pass
    
def load_model_accuracy():
    with open(hyper_param_tuning_input, 'rb') as handle:
        return pickle.load(handle)

def take_average(string):
    return np.mean(string.values())

# %% [markdown]
# Let's load the models with different optimizers/losses and check the average error rate, where average is the mean of training/testing error rate

# %%
models_accuracy_dict = load_model_accuracy()

# %%
#modify the dataframe's cells to get the average
df = pd.DataFrame(models_accuracy_dict)
df = df.applymap(take_average)

# %%
sns.set(font_scale=1.5)  #
fig, ax = plt.subplots(figsize=(10,10))        
sns.heatmap(df, annot=True)
plt.show()
