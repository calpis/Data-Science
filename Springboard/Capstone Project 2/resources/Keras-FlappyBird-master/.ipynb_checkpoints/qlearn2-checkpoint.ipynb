# %%
#!/usr/bin/env python
from __future__ import print_function


import os
##disable graphics for cloud computing
os.putenv('SDL_VIDEODRIVER', 'fbcon')
os.environ["SDL_VIDEODRIVER"] = "dummy"
import argparse
import skimage as skimage
from skimage import transform, color, exposure
from skimage.transform import rotate
from skimage.viewer import ImageViewer
import sys
sys.path.append("game/")
import wrapped_flappy_bird as game
import random
import numpy as np
from collections import deque
# Out:
# /anaconda2/lib/python2.7/site-packages/skimage/viewer/utils/core.py:10: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   warn("Recommended matplotlib backend is `Agg` for full "

# %%
import json
from keras import initializers
from keras.initializers import normal, identity
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers.core import Dense, Dropout, Activation, Flatten
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.optimizers import SGD , Adam
import tensorflow as tf
# Out:
# Using TensorFlow backend.

# %%
GAME = 'bird' # the name of the game being played for log files
CONFIG = 'nothreshold'
ACTIONS = 2 # number of valid actions
GAMMA = 0.99 # decay rate of past observations
OBSERVATION = 3200. # timesteps to observe before training
EXPLORE = 3000000. # frames over which to anneal epsilon
FINAL_EPSILON = 0.0001 # final value of epsilon
INITIAL_EPSILON = 1.0#0.1 # starting value of epsilon
REPLAY_MEMORY = 50000 # number of previous transitions to remember
BATCH = 32 # size of minibatch
FRAME_PER_ACTION = 1
LEARNING_RATE = 1e-4

# %%
img_rows , img_cols = 80, 80
#Convert image into Black and white
img_channels = 4 #We stack 4 frames

def buildmodel():
    print("Now we build the model")
    model = Sequential()
    model.add(Convolution2D(32, 8, 8, subsample=(4, 4), border_mode='same',input_shape=(img_rows,img_cols,img_channels)))  #80*80*4
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 4, 4, subsample=(2, 2), border_mode='same'))
    model.add(Activation('relu'))
    model.add(Convolution2D(64, 3, 3, subsample=(1, 1), border_mode='same'))
    model.add(Activation('relu'))
    model.add(Flatten())
    model.add(Dense(512))
    model.add(Activation('relu'))
    model.add(Dense(2))
   
    adam = Adam(lr=LEARNING_RATE)
    model.compile(loss='mse',optimizer=adam)
    print("We finish building the model")
    return model

# %%
def trainNetwork(model,args='train'):
    # open up a game state to communicate with emulator
    game_state = game.GameState()

    # store the previous observations in replay memory
    D = deque()

    # get the first state by doing nothing and preprocess the image to 80x80x4
    do_nothing = np.zeros(ACTIONS)
    do_nothing[0] = 1
    x_t, r_0, terminal = game_state.frame_step(do_nothing)

    x_t = skimage.color.rgb2gray(x_t)
    x_t = skimage.transform.resize(x_t,(80,80))
    x_t = skimage.exposure.rescale_intensity(x_t,out_range=(0,255))

    s_t = np.stack((x_t, x_t, x_t, x_t), axis=2)
    #print (s_t.shape)

    #In Keras, need to reshape
    s_t = s_t.reshape(1, s_t.shape[0], s_t.shape[1], s_t.shape[2])  #1*80*80*4

    

    if args == 'Run':
        print('running with saved model')
        OBSERVE = 999999999    #We keep observe, never train
        epsilon = FINAL_EPSILON
        print ("Now we load weight")
        model.load_weights("model.h5")
        adam = Adam(lr=LEARNING_RATE)
        model.compile(loss='mse',optimizer=adam)
        print ("Weight load successfully")    
    else:                       #We go to training mode
        OBSERVE = OBSERVATION
        epsilon = INITIAL_EPSILON

    t = 0
    while (True):
        loss = 0
        Q_sa = 0
        action_index = 0
        r_t = 0
        a_t = np.zeros([ACTIONS])
        #choose an action epsilon greedy
        if t % FRAME_PER_ACTION == 0:
            if random.random() <= epsilon:
                print("----------Random Action----------")
                if random.random() <= 0.95:
                    action_index=0
                else:
                    action_index=1
                #action_index = random.randrange(ACTIONS)
                a_t[action_index] = 1
            else:
                q = model.predict(s_t)       #input a stack of 4 images, get the prediction
                max_Q = np.argmax(q)
                action_index = max_Q
                a_t[max_Q] = 1

        #We reduced the epsilon gradually
        if epsilon > FINAL_EPSILON and t > OBSERVE:
            epsilon -= (INITIAL_EPSILON - FINAL_EPSILON) / EXPLORE

        #run the selected action and observed next state and reward
        x_t1_colored, r_t, terminal = game_state.frame_step(a_t)

        x_t1 = skimage.color.rgb2gray(x_t1_colored)
        x_t1 = skimage.transform.resize(x_t1,(80,80))
        x_t1 = skimage.exposure.rescale_intensity(x_t1, out_range=(0, 255))

        x_t1 = x_t1.reshape(1, x_t1.shape[0], x_t1.shape[1], 1) #1x80x80x1
        s_t1 = np.append(x_t1, s_t[:, :, :, :3], axis=3)

        # store the transition in D
        D.append((s_t, action_index, r_t, s_t1, terminal))
        if len(D) > REPLAY_MEMORY:
            D.popleft()

        #only train if done observing
        if t > OBSERVE:
            #sample a minibatch to train on
            minibatch = random.sample(D, BATCH)



            inputs = np.zeros((BATCH, s_t.shape[1], s_t.shape[2], s_t.shape[3]))   #32, 80, 80, 4
            print (inputs.shape)
            targets = np.zeros((inputs.shape[0], ACTIONS))                         #32, 2

            #Now we do the experience replay
            for i in range(0, len(minibatch)):
                state_t = minibatch[i][0]
                action_t = minibatch[i][1]   #This is action index
                reward_t = minibatch[i][2]
                state_t1 = minibatch[i][3]
                terminal = minibatch[i][4]
                # if terminated, only equals reward

                inputs[i:i + 1] = state_t    #I saved down s_t

                targets[i] = model.predict(state_t)  # Hitting each buttom probability
                Q_sa = model.predict(state_t1)

                if terminal:
                    targets[i, action_t] = reward_t
                else:
                    targets[i, action_t] = reward_t + GAMMA * np.max(Q_sa)

            # targets2 = normalize(targets)
            loss += model.train_on_batch(inputs, targets)

        s_t = s_t1
        t = t + 1

        # save progress every 10000 iterations
        if t % 1000 == 0:
            print("Now we save model")
            model.save_weights("model.h5", overwrite=True)
            with open("model.json", "w") as outfile:
                json.dump(model.to_json(), outfile)

        # print info
        state = ""
        if t <= OBSERVE:
            state = "observe"
        elif t > OBSERVE and t <= OBSERVE + EXPLORE:
            state = "explore"
        else:
            state = "train"

        print("TIMESTEP", t, "/ STATE", state, \
            "/ EPSILON", epsilon, "/ ACTION", action_index, "/ REWARD", r_t, \
            "/ Q_MAX " , np.max(Q_sa), "/ Loss ", loss)

    print("Episode finished!")
    print("************************")

# %%
def playGame(args='train'):
    model = buildmodel()
    trainNetwork(model,args)

def main():
    parser = argparse.ArgumentParser(description='Description of your program')
    parser.add_argument('-m','--mode', help='Train / Run', required=True)
    args = vars(parser.parse_args())
    playGame(args)

# %%
playGame()
# Out:
# Now we build the model
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 8), padding="same", strides=(4, 4), input_shape=(80, 80, 4...)`
#
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), padding="same", strides=(2, 2))`
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", strides=(1, 1))`
#   if sys.path[0] == '':
# We finish building the model
# ----------Random Action----------
# TIMESTEP 1 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 2 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 3 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 4 / STATE observe / EPSILON 1.0 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 5 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 6 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 7 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 8 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 9 / STATE observe / EPSILON 1.0 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 10 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 11 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 12 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 13 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 14 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 15 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 16 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 17 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 18 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 19 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 20 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 21 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 22 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 23 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 24 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 25 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 26 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 27 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 28 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 29 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 30 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 31 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 32 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 33 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 34 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 35 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 36 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 37 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 38 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 39 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 40 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 41 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 42 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 43 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 44 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 45 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 46 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 47 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 48 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 49 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD -1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP 50 / STATE observe / EPSILON 1.0 / ACTION 1 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ----------Random Action----------
# TIMESTEP
 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5600 / STATE explore / EPSILON 0.9992004133 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5601 / STATE explore / EPSILON 0.99920008 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5602 / STATE explore / EPSILON 0.9991997467 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5603 / STATE explore / EPSILON 0.9991994134 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5604 / STATE explore / EPSILON 0.9991990801 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5605 / STATE explore / EPSILON 0.9991987468 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5606 / STATE explore / EPSILON 0.9991984135 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5607 / STATE explore / EPSILON 0.9991980802 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5608 / STATE explore / EPSILON 0.9991977469 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5609 / STATE explore / EPSILON 0.9991974136 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5610 / STATE explore / EPSILON 0.9991970803 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5611 / STATE explore / EPSILON 0.999196747 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5612 / STATE explore / EPSILON 0.9991964137 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5613 / STATE explore / EPSILON 0.9991960804 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5614 / STATE explore / EPSILON 0.9991957471 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5615 / STATE explore / EPSILON 0.9991954138 / ACTION 0 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5616 / STATE explore / EPSILON 0.9991950805 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5617 / STATE explore / EPSILON 0.9991947472 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5618 / STATE explore / EPSILON 0.9991944139 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5619 / STATE explore / EPSILON 0.9991940806 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5620 / STATE explore / EPSILON 0.9991937473 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5621 / STATE explore / EPSILON 0.999193414 / ACTION 1 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# TIMESTEP 5622 / STATE explore / EPSILON 0.9991930807 / ACTION 0 / REWARD 0.1 / Q_MAX  nan / Loss  nan
# ----------Random Action----------
# (32, 80, 80, 4)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-7bf0dcea9dd9> in <module>()
# ----> 1 playGame()
#
# <ipython-input-10-ddb64465b217> in playGame(args)
#       1 def playGame(args='train'):
#       2     model = buildmodel()
# ----> 3     trainNetwork(model,args)
#       4
#       5 def main():
#
# <ipython-input-9-f2283aa66557> in trainNetwork(model, args)
#     109
#     110             # targets2 = normalize(targets)
# --> 111             loss += model.train_on_batch(inputs, targets)
#     112
#     113         s_t = s_t1
#
# /anaconda2/lib/python2.7/site-packages/keras/models.pyc in train_on_batch(self, x, y, class_weight, sample_weight)
#     979         return self.model.train_on_batch(x, y,
#     980                                          sample_weight=sample_weight,
# --> 981                                          class_weight=class_weight)
#     982
#     983     def test_on_batch(self, x, y,
#
# /anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in train_on_batch(self, x, y, sample_weight, class_weight)
#    1795             ins = x + y + sample_weights
#    1796         self._make_train_function()
# -> 1797         outputs = self.train_function(ins)
#    1798         if len(outputs) == 1:
#    1799             return outputs[0]
#
# /anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2330         updated = session.run(self.outputs + [self.updates_op],
#    2331                               feed_dict=feed_dict,
# -> 2332                               **self.session_kwargs)
#    2333         return updated[:len(self.outputs)]
#    2334
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     887     try:
#     888       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 889                          run_metadata_ptr)
#     890       if run_metadata:
#     891         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1118     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1119       results = self._do_run(handle, final_targets, final_fetches,
# -> 1120                              feed_dict_tensor, options, run_metadata)
#    1121     else:
#    1122       results = []
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1315     if handle is None:
#    1316       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1317                            options, run_metadata)
#    1318     else:
#    1319       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _do_call(self, fn, *args)
#    1321   def _do_call(self, fn, *args):
#    1322     try:
# -> 1323       return fn(*args)
#    1324     except errors.OpError as e:
#    1325       message = compat.as_text(e.message)
#
# /anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1300           return tf_session.TF_Run(session, options,
#    1301                                    feed_dict, fetch_list, target_list,
# -> 1302                                    status, run_metadata)
#    1303
#    1304     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
playGame(args='Run')
# Out:
# Now we build the model
# We finish building the model
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:8: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (8, 8), padding="same", strides=(4, 4), input_shape=(80, 80, 4...)`
#
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (4, 4), padding="same", strides=(2, 2))`
#   # Remove the CWD from sys.path while we load stuff.
# /anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3), padding="same", strides=(1, 1))`
#   if sys.path[0] == '':
# running with saved model
# Now we load weight
# Weight load successfully
# TIMESTEP 1 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 2 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 3 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 4 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 5 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 6 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 7 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 8 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 9 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 10 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 11 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 12 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 13 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 14 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 15 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 16 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 17 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 18 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 19 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 20 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 21 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 22 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 23 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 24 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 25 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 26 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 27 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 28 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 29 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 30 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 31 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 32 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 33 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 34 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 35 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 36 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 37 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 38 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 39 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 40 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 41 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 42 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 43 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 44 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 45 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 46 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 47 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 48 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 49 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 50 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 51 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 52 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 53 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP
/ STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 446 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 447 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 448 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 449 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 450 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 451 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 452 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 453 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 454 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 455 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 456 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 457 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 458 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 459 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 460 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 461 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 462 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 463 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 464 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 465 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 466 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 467 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 468 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 469 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 470 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 471 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 472 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 473 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 474 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 475 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 476 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 477 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 478 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 479 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 480 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 481 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 482 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 483 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 484 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 485 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 486 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 487 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 488 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 489 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 490 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 491 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 492 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 493 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 494 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 495 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 496 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 497 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 498 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 499 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 500 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 501 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 502 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 503 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 504 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 505 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 506 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 507 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 508 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 509 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 510 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 511 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 512 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 513 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 514 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 515 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 516 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 517 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 518 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 519 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 520 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ...
# TIMESTEP 1617 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1618 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1619 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1620 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1621 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1622 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1623 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1624 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1625 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1626 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1627 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1628 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1629 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1630 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1631 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1632 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1633 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1634 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1635 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1636 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1637 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1638 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1639 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1640 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1641 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1642 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1643 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1644 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1645 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1646 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1647 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1648 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1649 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1650 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1651 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1652 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1653 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1654 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1655 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1656 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1657 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1658 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1659 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1660 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1661 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1662 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1663 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1664 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1665 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1666 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1667 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1668 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1669 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1670 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1671 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1672 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1673 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1674 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1675 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1676 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1677 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1678 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1679 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1680 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1681 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1682 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1683 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1684 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1685 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1686 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1687 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1688 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1689 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1690 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1691 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1692 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1693 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1694 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1695 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1696 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1697 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1698 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1699 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1700 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1701 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1702 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1703 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1704 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1705 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1706 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1707 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1708 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1709 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1710 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1711 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1712 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1713 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1714 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1715 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1716 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1717 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1718 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1719 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1720 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1721 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1722 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1723 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1724 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1725 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1726 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1727 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1728 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1729 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1730 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1731 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1732 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1733 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1734 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1735 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1736 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1737 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1738 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1739 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1740 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1741 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1742 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1743 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1744 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1745 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1746 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1747 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1748 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1749 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1750 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1751 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1752 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1753 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1754 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1755 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1756 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1757 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1758 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1759 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1760 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1761 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1762 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1763 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1764 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1765 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1766 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD -1 / Q_MAX  0 / Loss  0
# TIMESTEP 1767 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1768 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1769 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1770 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1771 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1772 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1773 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1774 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1775 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1776 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# TIMESTEP 1777 / STATE observe / EPSILON 0.0001 / ACTION 0 / REWARD 0.1 / Q_MAX  0 / Loss  0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-03370c1ee794> in <module>()
# ----> 1 playGame(args='Run')
#
# <ipython-input-25-ddb64465b217> in playGame(args)
#       1 def playGame(args='train'):
#       2     model = buildmodel()
# ----> 3     trainNetwork(model,args)
#       4
#       5 def main():
#
# <ipython-input-27-5078a27a4a44> in trainNetwork(model, args)
#      60
#      61         #run the selected action and observed next state and reward
# ---> 62         x_t1_colored, r_t, terminal = game_state.frame_step(a_t)
#      63
#      64         x_t1 = skimage.color.rgb2gray(x_t1_colored)
#
# /Users/momori/Documents/GitHub/Data-Science/Springboard/Capstone Project 2/resources/Keras-FlappyBird-master/game/wrapped_flappy_bird.pyc in frame_step(self, input_actions)
#     142         pygame.display.update()
#     143         #print ("FPS" , FPSCLOCK.get_fps())
# --> 144         FPSCLOCK.tick(FPS)
#     145         #print self.upperPipes[0]['y'] + PIPE_HEIGHT - int(BASEY * 0.2)
#     146         return image_data, reward, terminal
#
# KeyboardInterrupt:

# %%
if __name__ == "__main__":
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    sess = tf.Session(config=config)
    from keras import backend as K
    K.set_session(sess)
    main()
# Out:
# usage: ipykernel_launcher.py [-h] -m MODE
# ipykernel_launcher.py: error: argument -m/--mode is required
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# /anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2890: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
